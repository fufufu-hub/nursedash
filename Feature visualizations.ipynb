# %% [markdown]
# ## Target- urgent withdrawn by nurse(within 24hr)
# * shift_applications status == 'cancelled' + shift_application prevStatus == 'confirmed'
#
#
# ### IDs -> only look at shifts application, leave each shifts after
# * shift_applications id
# * shift_applications user_id
# * shift_applications shift_id
#
#
# ### Numeric Field
# * shifts rate
# * shifts net_pay: rate - nursedash profit
# * shift_applications distance
# * shift break time
# * user withdrawn times:
#     Problem:
#         1. We don't know in reality that you will withdraw your previous one.
#         2. cannot be used to predict new user
# * user applied times:
# * prev SA/CW rate
#
#
# ## Time
# ### shift, shift app time
# * S_Create (shift created) => SA_Create (application created) => CWTime (comfim withdrawn) => Start_Time (shift start)
# * S_Create: shift create time
# * SA_Create: shift application create time
# * CWTime: shift withdrawn time, whole confirmed withdrawn population (include within 24hr and > 24hr)
# * Start_Time: shift start time
# ##### calculated field, graph in hours
# * S_Create2SA_Create: shift application create time - shift create time
# * S_Create2Start_Time: shift start time - shift create time
#         1. has negative values. delete maybe?
# * SA_Create2Start_Time: shift start time - shift application create time
#         1. has negative values. delete maybe?
#
# ### User
# * user approvedAt:
# * user createdAt:
# #### Calculated field
# * U_Create2U_approved: User approve time - User create time
# * U_Create2now: now - User create time, in months(seconds/2629746)
# * U_Approve2now: now - User approve time
#
#
# ### Categorical
# * shifts role: position name + type
# * facilities name = facilities short_name
# * facilities areaId = facilities areaName
# * withdrawnInfo_key, withdrawnInfo_value
# * facilities segmentName: Senior Living = 1, Healthcare = 0
# * Users enableNotifications:
# * Users emailNotifications:
# * Users appNotifications:
# * Users allowedNotifications:
#
#
# ### ?
# * facilities allowedQualification
# * facilities createdAt
# * facilities rates
# * nurse shift withdrawn by admin, when policy start, how many withdrawn by admin
# * shifts = unit
# * role
# * users updateAt ?
# * users relationToFacility

# %% [markdown]
# # ADD
#
# ### Facility

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv('main.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'user_id', 'shift_id', 'status', 'createdAt',
#        'hasNurseCheckEvent', 'hasBreakTime', 'prevStatus', 'distance', 'id.1',
#        'facility_id', 'description', 'start_time', 'assigned_nurse_id', 'rate',
#        'net_pay', 'unit', 'type', 'createdAt.1', 'qualifications', 'breakTime',
#        'prevStatus.1', 'id.2', 'name', 'short_name', 'createdAt.2', 'rates',
#        'S_Create', 'SA_Create', 'S_create2SA_Create', 'Start_Time',
#        'SA_Create2Start_Time', 'S_Create2Start_Time', 'CW_Time',
#        'CW_Time2Start_Time', 'SA_Create2CW_Time', 'S_Create2CW_Time',
#        'allowedQualifications', 'areaId', 'areaName', 'segmentName',
#        'U_create2now', 'U_approve2now', 'U_create2U_approve',
#        'withdrawnInfo_key', 'withdrawnInfo_value', 'tar'],
#       dtype='object')

# %%
df.shape
# Out:
# (169654, 48)

# %%
#df['tar'] = df.apply(lambda x: 1 if x['status'] == 'withdrawn' and x['prevStatus'] == 'confirmed' and x['withdrawnInfo_value'] == 'nurse' and df['CW_Time2Start_Time'] > -24 else 0, axis =1)

# %%
def CW_by_nurse(row):
    if row['status']=='withdrawn' and row['prevStatus'] == 'confirmed':
        if row['withdrawnInfo_value'] != 'admin':
            if row['CW_Time2Start_Time'] < 0 and row['CW_Time2Start_Time'] >= -24:
                return 1
            else:
                return 0
        else:
            return 0
    else:
        return 0
    
df['target'] = df.apply (lambda row: CW_by_nurse(row), axis=1)

# %%
df['target'].value_counts()
# Out:
# 0    160197
# 1      9457
# Name: target, dtype: int64

# %%
9457/169654
# Out:
# 0.05574286488971672

# %% [markdown]
# #### Calculated field
# * U_Create2U_approve: User approve time - User create time
# * U_Create2now: now - User create time, in months(seconds/2629746)
# * U_Approve2now: now - User approve time

# %%
import seaborn as sns
from matplotlib import pyplot

# %%
# U_create to U_approve (by hours)
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "U_create2U_approve",showfliers=False)

# %%
# U_create to now (by month)
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "U_create2now",showfliers=False)

# %%
# U_approve to now (by month)
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "U_approve2now",showfliers=False)

# %% [markdown]
# ##### calculated field, graph in hours
# * S_Create2SA_Create: shift application create time - shift create time
# * S_Create2Start_Time: shift start time - shift create time
# * SA_Create2Start_Time: shift start time - shift application create time

# %%
# S_Create to SA_Create (by hour)
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "S_create2SA_Create",showfliers=False)

# %%
# S_Create to Start_Time (by hour)
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "S_Create2Start_Time",showfliers=False)

# %%
# There are some negative numbers in this column. Not very much. 
# I think we need to delete these data entries since it make it impossible to nurse to apply on time.
df[df["S_Create2Start_Time"]<0].shape[0]
# Out:
# 388

# %%
# SA_Create to Start_Time (by hour)
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "SA_Create2Start_Time",showfliers=False)

# %%
# There are some negative numbers in this column. Not very much. 
# I think we need to delete these data entries since it make it impossible to nurse to apply on time.
df[df["SA_Create2Start_Time"]<0].shape[0]
# Out:
# 1931

# %%
import numpy as np

# %%
# df2 is a sorted version of df1, data is exactly the same
df1 = df.set_index(['user_id','id'])
df2 = df1.sort_index()
df2 = df2.reset_index()

# %%
# df2.head(50)

# %%
def count_prev_SA(df):
    count_prev_SA = []
    id_number = 0
    count = 0
    user_id = list(df2['user_id'])
    for i in user_id:
        if id_number == i:
            count += 1
            count_prev_SA.append(count)
            id_number = i
        else:
            count = 0
            count_prev_SA.append(count)
            id_number = i
    return count_prev_SA

        
df2['count_prev_SA'] = count_prev_SA(df2)

# %%
def count_prev_CW(df):
    count_prev_CW = []
    id_number = 0
    count = 0
    user_id = list(df2['user_id'])
    urgent_CW = list(df2['target'])
    for i,v in enumerate(user_id):
        if id_number == v:
            count_prev_CW.append(count)
            if urgent_CW[i] == 1:
                count += 1
            id_number = v
        else:
            count = 0
            count_prev_CW.append(count)
            if urgent_CW[i] == 1:
                count += 1
            id_number = v
    return count_prev_CW

        
df2['count_prev_CW'] = count_prev_CW(df2)

# %%
df2['prev_CW/SA_rate'] = df2['count_prev_CW']/df2['count_prev_SA']
df2['prev_CW/SA_rate'].fillna(0,inplace=True)

# %%
# prev_CW/SA_rate
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df2,x = "target", y = "prev_CW/SA_rate",showfliers=False)

# %%
df2.head(60)
# Out:
#     user_id      id  Unnamed: 0  shift_id       status  \
# 0        18   29072         650     12460      applied
# 1        18   29706        1473     12685      applied
# 2        18   36042        9226     15920    confirmed
# 3        18   40273       14136     17541    confirmed
# 4        18   40656       14639     17809   interested
# 5        18   40657       14614     17796      applied
# 6        18   40759       14612     17795      applied
# 7        18   40760       14873     17920    confirmed
# 8        18   43574       18500     19122    confirmed
# 9        18   45071       19830     19564      applied
# 10       18   50119       25828     22396    confirmed
# 11       18   50130       25837     22405    confirmed
# 12       18   50134       25838     22407      applied
# 13       18   50135       25839     22408      applied
# 14       18   51552       27735     23475    confirmed
# 15       18   54671       31075     25302    withdrawn
# 16       18   54671       31076     25302    withdrawn
# 17       18   57982       34175     28458    confirmed
# 18       18   78216        8447     46051      applied
# 19       18   78877        9171     47092      applied
# 20       18   78966        9354     47291    confirmed
# 21       18   79830       10685     48823    confirmed
# 22       18   80096       11129     49229    confirmed
# 23       18   81061       12517     50480    confirmed
# 24       18   82332       14250     52151      applied
# 25       18   84415       16575     53922    confirmed
# 26       18   87233       21028     57087    confirmed
# 27       18   94900       28420     61870      applied
# 28       18  101774        5118     66785    confirmed
# 29       18  101806        5155     66803     selected
# 30       18  109158       13825     71065  unavailable
# 31       18  109159       13823     71064    confirmed
# 32       18  109160       13826     71066     selected
# 33       18  109291       13915     71119    confirmed
# 34       18  110561       15813     71982     selected
# 35       18  111906       16969     72739    withdrawn
# 36       18  111906       16970     72739    withdrawn
# 37       18  111924       16794     72642   interested
# 38       18  111926       16984     72746    withdrawn
# 39       18  111926       16985     72746    withdrawn
# 40       18  111929       17045     72760    confirmed
# 41       18  112069       16964     72737   interested
# 42       18  112103       17350     72842    confirmed
# 43       18  112304       17633     72988     selected
# 44       18  112421       16968     72738      applied
# 45       18  115679       22568     75920   interested
# 46       18  115686       22567     75919    confirmed
# 47       18  135489       46973     93134    confirmed
# 48       18  135490       46974     93136    confirmed
# 49       18  135514       46983     93154    confirmed
# 50       18  135545       47191     93257    confirmed
# 51       18  135554       47210     93291    confirmed
# 52       18  135555       47213     93301     selected
# 53       18  135999       46381     92303      applied
# 54       18  136000       47211     93296     selected
# 55       18  144574        9311    101261    confirmed
# 56       18  144862       10258    102527    confirmed
# 57       18  146418       12408    103562    confirmed
# 58       18  146419       10267    102536    confirmed
# 59       18  151210       19611    108016     selected
#
#                      createdAt hasNurseCheckEvent hasBreakTime prevStatus  \
# 0   2019-09-11 17:58:36.854268                  f            f  withdrawn
# 1   2019-09-16 16:19:11.890038                  f            f        NaN
# 2   2019-10-29 01:59:31.169775                  t            f   selected
# 3   2019-11-18 20:14:34.591996                  t            t   selected
# 4   2019-11-20 03:53:30.618811                  f            f    applied
# 5   2019-11-20 03:57:07.474308                  f            f        NaN
# 6   2019-11-20 16:37:14.192365                  f            f        NaN
# 7   2019-11-20 16:37:53.532838                  f          NaN   selected
# 8   2019-12-05 17:17:14.436798                  t            t   selected
# 9   2019-12-12 22:02:43.231228                  f            f   selected
# 10  2020-01-17 12:38:25.573842                  t            f   selected
# 11  2020-01-17 15:42:59.658392                  t            f   selected
# 12  2020-01-17 15:52:31.302535                  f            f        NaN
# 13  2020-01-17 15:52:48.266219                  f            f        NaN
# 14  2020-01-28 17:25:22.593795                  f          NaN   selected
# 15  2020-02-18 22:41:40.044504                  f            f    applied
# 16  2020-02-18 22:41:40.044504                  f            f    applied
# 17  2020-03-12 12:09:00.047439                  t            f   selected
# 18  2020-07-16 19:15:05.001577                  f            f        NaN
# 19  2020-07-22 20:01:36.702048                  f            f        NaN
# 20  2020-07-23 15:20:09.578639                  f            f   selected
# 21  2020-07-29 02:59:53.253656                  f            f   selected
# 22  2020-07-30 15:48:06.013803                  f            f   selected
# 23  2020-08-04 19:07:07.673305                  f            f   selected
# 24  2020-08-11 18:50:07.719333                  f            f        NaN
# 25  2020-08-20 18:23:37.905314                  f            f   selected
# 26  2020-09-01 19:03:20.941038                  f          NaN   selected
# 27  2020-09-25 18:38:11.914792                  f            f        NaN
# 28  2020-10-15 14:04:08.352984                  f          NaN   selected
# 29  2020-10-15 14:55:42.231357                  f            f    applied
# 30  2020-11-02 22:21:58.757597                  f            f    applied
# 31  2020-11-02 22:22:04.124059                  f          NaN   selected
# 32  2020-11-02 22:22:12.613618                  f            f    applied
# 33  2020-11-03 13:48:25.341297                  f          NaN   selected
# 34  2020-11-06 18:34:20.515421                  f            f    applied
# 35  2020-11-10 20:56:49.027625                  f          NaN  confirmed
# 36  2020-11-10 20:56:49.027625                  f          NaN  confirmed
# 37  2020-11-10 21:34:07.842681                  f            f    applied
# 38  2020-11-10 21:36:35.068451                  f            f  confirmed
# 39  2020-11-10 21:36:35.068451                  f            f  confirmed
# 40  2020-11-10 21:45:25.737875                  f            f   selected
# 41  2020-11-11 02:46:49.032180                  f            f    applied
# 42  2020-11-11 04:16:41.028715                  f            f   selected
# 43  2020-11-11 22:33:10.104461                  f            f    applied
# 44  2020-11-12 14:58:35.789480                  f            f        NaN
# 45  2020-11-19 21:31:15.387695                  f            f    applied
# 46  2020-11-19 21:35:20.756568                  f          NaN   selected
# 47  2020-12-31 12:25:06.050438                  t            f   selected
# 48  2020-12-31 12:40:15.796354                  t            f   selected
# 49  2020-12-31 14:14:16.290950                  t            f   selected
# 50  2020-12-31 15:43:22.728957                  t            f   selected
# 51  2020-12-31 16:15:40.646430                  f            f   selected
# 52  2020-12-31 16:15:52.842561                  f            f    applied
# 53  2021-01-01 17:48:21.540120                  f            f        NaN
# 54  2021-01-01 17:48:30.346805                  f            f    applied
# 55  2021-01-22 03:21:55.208896                  f          NaN   selected
# 56  2021-01-22 19:16:59.896080                  t          NaN   selected
# 57  2021-01-26 17:01:26.383366                  f          NaN   selected
# 58  2021-01-26 17:01:56.901129                  f          NaN   selected
# 59  2021-02-04 19:34:41.693975                  f            f    applied
#
#     distance  ...  U_create2now  U_approve2now U_create2U_approve  \
# 0        NaN  ...     31.272810      24.076044          219.04706
# 1        NaN  ...     31.272810      24.076044          219.04706
# 2        NaN  ...     31.272810      24.076044          219.04706
# 3        NaN  ...     31.272810      24.076044          219.04706
# 4        NaN  ...     31.272810      24.076044          219.04706
# 5        NaN  ...     31.272810      24.076044          219.04706
# 6        NaN  ...     31.272810      24.076044          219.04706
# 7        NaN  ...     31.272810      24.076044          219.04706
# 8        NaN  ...     31.272810      24.076044          219.04706
# 9        NaN  ...     31.272810      24.076044          219.04706
# 10       NaN  ...     31.272810      24.076044          219.04706
# 11       NaN  ...     31.272810      24.076044          219.04706
# 12       NaN  ...     31.272810      24.076044          219.04706
# 13       NaN  ...     31.272810      24.076044          219.04706
# 14       NaN  ...     31.272810      24.076044          219.04706
# 15       NaN  ...     31.272810      24.076044          219.04706
# 16       NaN  ...     31.272810      24.076044          219.04706
# 17       NaN  ...     31.272810      24.076044          219.04706
# 18       NaN  ...     31.272710      24.075945          219.04706
# 19       NaN  ...     31.272710      24.075945          219.04706
# 20       NaN  ...     31.272710      24.075945          219.04706
# 21       NaN  ...     31.272710      24.075945          219.04706
# 22       NaN  ...     31.272710      24.075945          219.04706
# 23       NaN  ...     31.272710      24.075945          219.04706
# 24       NaN  ...     31.272710      24.075945          219.04706
# 25       NaN  ...     31.272710      24.075945          219.04706
# 26       NaN  ...     31.272710      24.075945          219.04706
# 27       NaN  ...     31.272710      24.075945          219.04706
# 28       NaN  ...     31.272647      24.075881          219.04706
# 29       NaN  ...     31.272647      24.075881          219.04706
# 30       NaN  ...     31.272647      24.075881          219.04706
# 31       NaN  ...     31.272647      24.075881          219.04706
# 32       NaN  ...     31.272647      24.075881          219.04706
# 33       NaN  ...     31.272647      24.075881          219.04706
# 34       NaN  ...     31.272647      24.075881          219.04706
# 35  253299.0  ...     31.272647      24.075881          219.04706
# 36  253299.0  ...     31.272647      24.075881          219.04706
# 37  253299.0  ...     31.272647      24.075881          219.04706
# 38  253299.0  ...     31.272647      24.075881          219.04706
# 39  253299.0  ...     31.272647      24.075881          219.04706
# 40  253299.0  ...     31.272647      24.075881          219.04706
# 41  253299.0  ...     31.272647      24.075881          219.04706
# 42  253299.0  ...     31.272647      24.075881          219.04706
# 43  253299.0  ...     31.272647      24.075881          219.04706
# 44  253299.0  ...     31.272647      24.075881          219.04706
# 45  253299.0  ...     31.272647      24.075881          219.04706
# 46  253299.0  ...     31.272647      24.075881          219.04706
# 47  253299.0  ...     31.272647      24.075881          219.04706
# 48     505.0  ...     31.272647      24.075881          219.04706
# 49     474.0  ...     31.272647      24.075881          219.04706
# 50     474.0  ...     31.272647      24.075881          219.04706
# 51     474.0  ...     31.272647      24.075881          219.04706
# 52     474.0  ...     31.272647      24.075881          219.04706
# 53     474.0  ...     31.272647      24.075881          219.04706
# 54     474.0  ...     31.272647      24.075881          219.04706
# 55     474.0  ...     31.272588      24.075822          219.04706
# 56     474.0  ...     31.272588      24.075822          219.04706
# 57     474.0  ...     31.272588      24.075822          219.04706
# 58     474.0  ...     31.272588      24.075822          219.04706
# 59     474.0  ...     31.272588      24.075822          219.04706
#
#    withdrawnInfo_key   withdrawnInfo_value  tar  target  count_prev_SA  \
# 0                NaN                   NaN    0       0              0
# 1                NaN                   NaN    0       0              1
# 2                NaN                   NaN    0       0              2
# 3                NaN                   NaN    0       0              3
# 4                NaN                   NaN    0       0              4
# 5                NaN                   NaN    0       0              5
# 6                NaN                   NaN    0       0              6
# 7                NaN                   NaN    0       0              7
# 8                NaN                   NaN    0       0              8
# 9                NaN                   NaN    0       0              9
# 10               NaN                   NaN    0       0             10
# 11               NaN                   NaN    0       0             11
# 12               NaN                   NaN    0       0             12
# 13               NaN                   NaN    0       0             13
# 14               NaN                   NaN    0       0             14
# 15         initiator                 nurse    0       0             15
# 16           comment      Test your email     0       0             16
# 17               NaN                   NaN    0       0             17
# 18               NaN                   NaN    0       0             18
# 19               NaN                   NaN    0       0             19
# 20               NaN                   NaN    0       0             20
# 21               NaN                   NaN    0       0             21
# 22               NaN                   NaN    0       0             22
# 23               NaN                   NaN    0       0             23
# 24               NaN                   NaN    0       0             24
# 25               NaN                   NaN    0       0             25
# 26               NaN                   NaN    0       0             26
# 27               NaN                   NaN    0       0             27
# 28               NaN                   NaN    0       0             28
# 29               NaN                   NaN    0       0             29
# 30               NaN                   NaN    0       0             30
# 31               NaN                   NaN    0       0             31
# 32               NaN                   NaN    0       0             32
# 33               NaN                   NaN    0       0             33
# 34               NaN                   NaN    0       0             34
# 35         initiator                 nurse    1       0             35
# 36           comment  Testing new version     0       0             36
# 37               NaN                   NaN    0       0             37
# 38         initiator                 nurse    1       0             38
# 39           comment   Testable withdraws     0       0             39
# 40               NaN                   NaN    0       0             40
# 41               NaN                   NaN    0       0             41
# 42               NaN                   NaN    0       0             42
# 43               NaN                   NaN    0       0             43
# 44               NaN                   NaN    0       0             44
# 45               NaN                   NaN    0       0             45
# 46               NaN                   NaN    0       0             46
# 47               NaN                   NaN    0       0             47
# 48               NaN                   NaN    0       0             48
# 49               NaN                   NaN    0       0             49
# 50               NaN                   NaN    0       0             50
# 51               NaN                   NaN    0       0             51
# 52               NaN                   NaN    0       0             52
# 53               NaN                   NaN    0       0             53
# 54               NaN                   NaN    0       0             54
# 55               NaN                   NaN    0       0             55
# 56               NaN                   NaN    0       0             56
# 57               NaN                   NaN    0       0             57
# 58               NaN                   NaN    0       0             58
# 59               NaN                   NaN    0       0             59
#
#    count_prev_CW prev_CW/SA_rate
# 0              0             0.0
# 1              0             0.0
# 2              0             0.0
# 3              0             0.0
# 4              0             0.0
# 5              0             0.0
# 6              0             0.0
# 7              0             0.0
# 8              0             0.0
# 9              0             0.0
# 10             0             0.0
# 11             0             0.0
# 12             0             0.0
# 13             0             0.0
# 14             0             0.0
# 15             0             0.0
# 16             0             0.0
# 17             0             0.0
# 18             0             0.0
# 19             0             0.0
# 20             0             0.0
# 21             0             0.0
# 22             0             0.0
# 23             0             0.0
# 24             0             0.0
# 25             0             0.0
# 26             0             0.0
# 27             0             0.0
# 28             0             0.0
# 29             0             0.0
# 30             0             0.0
# 31             0             0.0
# 32             0             0.0
# 33             0             0.0
# 34             0             0.0
# 35             0             0.0
# 36             0             0.0
# 37             0             0.0
# 38             0             0.0
# 39             0             0.0
# 40             0             0.0
# 41             0             0.0
# 42             0             0.0
# 43             0             0.0
# 44             0             0.0
# 45             0             0.0
# 46             0             0.0
# 47             0             0.0
# 48             0             0.0
# 49             0             0.0
# 50             0             0.0
# 51             0             0.0
# 52             0             0.0
# 53             0             0.0
# 54             0             0.0
# 55             0             0.0
# 56             0             0.0
# 57             0             0.0
# 58             0             0.0
# 59             0             0.0
#
# [60 rows x 52 columns]

# %%
df2[['target','user_id', 'CW_Time2Start_Time', 'CW_Time', 'Start_Time', 'withdrawnInfo_value']][60:90]
# Out:
#     target  user_id  CW_Time2Start_Time                     CW_Time  \
# 60       0       18                 NaN                         NaN
# 61       0       18                 NaN                         NaN
# 62       0       18                 NaN                         NaN
# 63       0       31           13.988056  2019-10-02 20:44:17.376000
# 64       0       31                 NaN                         NaN
# 65       0       31           -8.648889  2019-10-09 22:06:04.454000
# 66       0       31                 NaN                         NaN
# 67       0       31          -54.616667  2019-10-08 12:07:59.693000
# 68       0       31                 NaN                         NaN
# 69       0       31                 NaN                         NaN
# 70       0       31                 NaN                         NaN
# 71       0       31                 NaN                         NaN
# 72       0       31                 NaN                         NaN
# 73       0       31                 NaN                         NaN
# 74       0       31                 NaN                         NaN
# 75       0       31                 NaN                         NaN
# 76       0       31                 NaN                         NaN
# 77       0       31          -39.302222  2019-11-04 15:26:51.617000
# 78       0       31          -39.302222  2019-11-04 15:26:51.617000
# 79       0       31         -106.265556  2019-11-02 05:14:03.519000
# 80       0       31         -106.265556  2019-11-02 05:14:03.519000
# 81       0       31                 NaN                         NaN
# 82       0       31                 NaN                         NaN
# 83       0       31            1.136389  2019-11-10 07:53:10.693000
# 84       0       31                 NaN                         NaN
# 85       0       31                 NaN                         NaN
# 86       0       31                 NaN                         NaN
# 87       0       31                 NaN                         NaN
# 88       0       31          -21.034167  2019-11-25 09:42:56.692000
# 89       0       31                 NaN                         NaN
#
#                     Start_Time      withdrawnInfo_value
# 60  2021-02-04 14:00:00.000000                      NaN
# 61  2021-02-11 06:00:00.000000                      NaN
# 62  2021-02-10 14:00:00.000000                      NaN
# 63  2019-10-02 06:45:00.000000                      NaN
# 64  2019-10-02 11:00:00.000000                      NaN
# 65  2019-10-10 06:45:00.000000                      NaN
# 66  2019-10-09 06:45:00.000000                      NaN
# 67  2019-10-10 18:45:00.000000                      NaN
# 68  2019-10-12 06:45:00.000000                      NaN
# 69  2019-10-16 06:45:00.000000                      NaN
# 70  2019-10-18 06:45:00.000000                      NaN
# 71  2019-10-23 06:45:00.000000                      NaN
# 72  2019-10-25 06:45:00.000000                      NaN
# 73  2019-10-26 06:45:00.000000                      NaN
# 74  2019-10-27 06:45:00.000000                      NaN
# 75  2019-10-31 07:00:00.000000                      NaN
# 76  2019-11-04 06:45:00.000000                      NaN
# 77  2019-11-06 06:45:00.000000                    nurse
# 78  2019-11-06 06:45:00.000000  No reply from facility
# 79  2019-11-06 15:30:00.000000                    nurse
# 80  2019-11-06 15:30:00.000000             Time change
# 81  2019-11-06 06:45:00.000000                      NaN
# 82  2019-11-09 06:45:00.000000                      NaN
# 83  2019-11-10 06:45:00.000000                      NaN
# 84  2019-11-19 06:45:00.000000                      NaN
# 85  2019-11-23 07:00:00.000000                      NaN
# 86  2019-12-02 06:45:00.000000                      NaN
# 87  2019-11-25 06:45:00.000000                      NaN
# 88  2019-11-26 06:45:00.000000                      NaN
# 89  2019-12-07 06:45:00.000000                      NaN

# %%
df2[df2['user_id'].apply(lambda x: x == 31)]
# Out:
#      user_id      id  Unnamed: 0  shift_id      status  \
# 63        31   31724        3989     13949   cancelled
# 64        31   31735        3139     13332  interested
# 65        31   31804        3654     13830   cancelled
# 66        31   32651        5289     14416   confirmed
# 67        31   32655        5219     14402   cancelled
# ..       ...     ...         ...       ...         ...
# 203       31  130022       39888     86677   cancelled
# 204       31  142974        3298     95672   confirmed
# 205       31  142977        3352     95736   confirmed
# 206       31  142980        3515     95832   confirmed
# 207       31  142981        4345     96862   confirmed
#
#                       createdAt hasNurseCheckEvent hasBreakTime  prevStatus  \
# 63   2019-10-01 17:01:54.900035                  f            f     applied
# 64   2019-10-01 18:00:29.892732                  f            f     applied
# 65   2019-10-01 22:59:02.337373                  f            f  interested
# 66   2019-10-07 18:40:32.248326                  t            t    selected
# 67   2019-10-07 18:41:13.019800                  f            f     applied
# ..                          ...                ...          ...         ...
# 203  2020-12-18 19:01:28.300459                  f            f   confirmed
# 204  2021-01-17 21:54:27.889718                  t            f    selected
# 205  2021-01-17 21:58:49.230925                  t            f    selected
# 206  2021-01-17 22:03:32.746063                  t            f    selected
# 207  2021-01-17 22:05:01.698410                  t            f    selected
#
#      distance  ...  U_create2now  U_approve2now U_create2U_approve  \
# 63        NaN  ...     31.272810      24.008872         221.091551
# 64        NaN  ...     31.272810      24.008872         221.091551
# 65        NaN  ...     31.272810      24.008872         221.091551
# 66        NaN  ...     31.272810      24.008872         221.091551
# 67        NaN  ...     31.272810      24.008872         221.091551
# ..        ...  ...           ...            ...                ...
# 203   83739.0  ...     31.272647      24.008710         221.091551
# 204   83739.0  ...     31.272588      24.008650         221.091551
# 205   83739.0  ...     31.272588      24.008650         221.091551
# 206   83739.0  ...     31.272588      24.008650         221.091551
# 207   83739.0  ...     31.272588      24.008650         221.091551
#
#     withdrawnInfo_key  withdrawnInfo_value  tar  target  count_prev_SA  \
# 63                NaN                  NaN    0       0              0
# 64                NaN                  NaN    0       0              1
# 65                NaN                  NaN    0       0              2
# 66                NaN                  NaN    0       0              3
# 67                NaN                  NaN    0       0              4
# ..                ...                  ...  ...     ...            ...
# 203               NaN                  NaN    0       0            140
# 204               NaN                  NaN    0       0            141
# 205               NaN                  NaN    0       0            142
# 206               NaN                  NaN    0       0            143
# 207               NaN                  NaN    0       0            144
#
#     count_prev_CW prev_CW/SA_rate
# 63              0        0.000000
# 64              0        0.000000
# 65              0        0.000000
# 66              0        0.000000
# 67              0        0.000000
# ..            ...             ...
# 203             4        0.028571
# 204             4        0.028369
# 205             4        0.028169
# 206             4        0.027972
# 207             4        0.027778
#
# [145 rows x 52 columns]

# %% [markdown]
# ### Additional User Analysis for potential user analysis

# %%
user_info = pd.DataFrame(df1.groupby('user_id')['target'].sum()).drop(['target'], axis=1)
count_CW = list(df1.groupby('user_id')['target'].sum())
count_SA = list(df1.groupby('user_id')['target'].count())
user_info['count_CW'] = count_CW
user_info['count_SA'] = count_SA
user_info['CW/SA_rate'] = user_info['count_CW']/user_info['count_SA']

# %%
user_info
# Out:
#          count_CW  count_SA  CW/SA_rate
# user_id
# 18              0        63    0.000000
# 31              4       145    0.027586
# 32              0         4    0.000000
# 38              0         7    0.000000
# 39              0         8    0.000000
# ...           ...       ...         ...
# 16986           0         2    0.000000
# 17002           0         4    0.000000
# 17027           0         1    0.000000
# 17085           4         5    0.800000
# 17143           0         7    0.000000
#
# [3090 rows x 3 columns]

# %% [markdown]
# # Numeric Field
# ### shifts rate

# %%
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df2,x = "target", y = "rate",showfliers=False)

# %% [markdown]
# ### <font color = red> useless

# %% [markdown]
# ### shifts net_pay: rate - nursedash profit

# %%
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "net_pay",showfliers=False)

# %% [markdown]
# ### <font color = red> useless

# %% [markdown]
# ### shift_applications distance, box plot bad

# %%
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df,x = "target", y = "distance",showfliers=False)

# %%
df[['distance', 'target']].dropna()['target'].value_counts()
# Out:
# 0    55218
# 1     3891
# Name: target, dtype: int64

# %%
import math
math.isnan(df2['distance'][0])

# %%
df

# %%
avg = []
userid = list(pd.unique(df['user_id']))
for i in range(len(list(pd.unique(df['user_id'])))):
    test = df['distance'][df['user_id'].apply(lambda x: x == userid[i])].dropna()
    average = (sum(test) - min(test) - max(test))/(len(test) - 2)
    avg.append(average)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-352-389dc3eb798e> in <module>
#       2 userid = list(pd.unique(df['user_id']))
#       3 for i in range(len(list(pd.unique(df['user_id'])))):
# ----> 4     test = df['distance'][df['user_id'].apply(lambda x: x == userid[i])].dropna()
#       5     average = (sum(test) - min(test) - max(test))/(len(test) - 2)
#       6     avg.append(average)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-352-389dc3eb798e> in <lambda>(x)
#       2 userid = list(pd.unique(df['user_id']))
#       3 for i in range(len(list(pd.unique(df['user_id'])))):
# ----> 4     test = df['distance'][df['user_id'].apply(lambda x: x == userid[i])].dropna()
#       5     average = (sum(test) - min(test) - max(test))/(len(test) - 2)
#       6     avg.append(average)
#
# KeyboardInterrupt:

# %%
len(avg)

# %%
userid[184]
# Out:
# 6946

# %%
v = 7108
test = df['distance'][df['user_id'].apply(lambda x: x == v)].dropna()
len(test)

# %%
average = (sum(test) - min(test) - max(test))/(len(test) - 2)
average

# %%
sum(test)
# Out:
# nan

# %% [markdown]
# ### <font color = red> Really significant, but lots of nas

# %% [markdown]
# # Categorical
# ### shifts role: position name + type, only type

# %%
test1 = pd.DataFrame(df2.groupby('type')['target'].count().reset_index(name = 'total count'))

# %%
test1 = pd.DataFrame(df2.groupby('type')['target'].count().reset_index(name = 'total count'))

shiftrole_cw = df2[df['target'].apply(lambda x: x == 1)]
test2 = pd.DataFrame(shiftrole_cw.groupby('type')['target'].count().reset_index(name = 'cw count'))

g1 = test1.merge(test2, on = 'type', how = 'left')

g1['rf'] = g1.apply(lambda x: x['cw count']/x['total count'], axis = 1)

g1.sort_values(by = 'rf', ascending = False)
# Out:
#            type  total count  cw count        rf
# 6          Tech         1070        34  0.031776
# 0  CMA/Med-Tech         6345       172  0.027108
# 5          STNA        40486      1058  0.026132
# 1           CNA        86989      2256  0.025934
# 3           LVN        16449       420  0.025533
# 4            RN        11755       279  0.023735
# 2           LPN         6560       151  0.023018

# %%
# prev_CW/SA_rate
size = (10, 7)
fig, ax = pyplot.subplots(figsize=size)
sns.boxplot(data = df2,x = 'type', y = 'net_pay',showfliers=False)

# %%
# create type dummy: RN = 1, LVN + LPN = 2, rest = 0
def create_type_dummy(row):
    if row['type']=='RN':
        return 1
    elif row['type'] == 'LVN' or row['type'] == 'LPN':
        return 2
    else:
        return 0
    
df2['type_d'] = df2.apply(lambda row: create_type_dummy(row), axis=1)

# %%
df2['type_d']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 169649    2
# 169650    2
# 169651    2
# 169652    2
# 169653    2
# Name: type_d, Length: 169654, dtype: int64

# %% [markdown]
# ### <font color = red> three dummmy, RN, LVN + LPN, rest

# %% [markdown]
# ### facilities name = facilities short_name

# %%
df2['short_name'].value_counts().reset_index(name = 'count').head(20)
# Out:
#           index  count
# 0       MTF-SNF   9795
# 1           MCG   7619
# 2           SCV   4880
# 3   ADH-Heights   4620
# 4           BRE   4063
# 5           ABP   3927
# 6          NXCH   3573
# 7           VOH   3473
# 8           WEI   3444
# 9          PMSB   3108
# 10          HMK   2907
# 11          SCL   2884
# 12     ROHC-ADH   2859
# 13         LASB   2843
# 14          COL   2682
# 15          WGC   2640
# 16         NSHS   2493
# 17         HCND   2315
# 18        PKWDC   2282
# 19         NXNC   2278

# %% [markdown]
# ### <font color = red> later with areaID

# %% [markdown]
# ### facilities areaId = facilities areaName

# %%
df2['areaName'].value_counts()
# Out:
# Houston           85321
# Northeast Ohio    47353
# DFW               27350
# Austin             6120
# San Antonio        3451
# Cincinnati           59
# Name: areaName, dtype: int64

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(df2, col = 'areaName')
# Notice hwo the arguments come after plt.scatter call
g = g.map(sns.boxplot, 'target', 'net_pay').add_legend()
# Out:
# /Users/fufufu/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ### <font color = red> later with areaID

# %% [markdown]
# ### withdrawnInfo_value need to trace forward

# %%
df2['withdrawnInfo_value'].value_counts()[:10]
# Out:
# nurse                                  27767
# admin                                   6492
# Set "do not return" to the facility     1350
# Set nurse status to on hold             1099
# Family emergency                         342
# Wrong shift                              332
# Wrong shift                              260
# Not available                            259
# Wrong date                               229
# Unavailable                              213
# Name: withdrawnInfo_value, dtype: int64

# %%
w_familyemergency = df2[df2['withdrawnInfo_value'].apply(lambda x: x == 'Family emergency')]
sns.countplot(x = 'target', data = w_familyemergency)

# %%
userindex = list(df2[df2['withdrawnInfo_value'].apply(lambda x: x == 'Family emergency')]['user_id'])
userindex[:3]
# Out:
# [230, 568, 664]

# %%
# list(df2[df2['user_id'].apply(lambda x: x == 568)]['withdrawnInfo_value'])
# 'Confirmed to work elsewhere ',
# 'Confirmed for shift elsewhere; applied to this shift several days ago without a response',

# %%
# list(df2[df2['user_id'].apply(lambda x: x == 664)]['withdrawnInfo_value'])
# 'Got another shift on nursedash',
# 'The time is past and my application was not approved',

# %% [markdown]
# #### 'Set nurse status to on hold'

# %%
w_familyemergency = df2[df2['withdrawnInfo_value'].apply(lambda x: x == 'Set nurse status to on hold')]
sns.countplot(x = 'target', data = w_familyemergency)

# %%
userindex = list(df2[df2['withdrawnInfo_value'].apply(lambda x: x == 'Set nurse status to on hold')]['user_id'])
userindex[:3]
# Out:
# [194, 405, 555]

# %%
list(df2[df2['user_id'].apply(lambda x: x == 405)]['withdrawnInfo_value'])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'admin',
#  nan,
#  'admin',
#  nan,
#  'nurse',
#  'Working a different location ',
#  'admin',
#  nan,
#  'nurse',
#  'Another location',
#  nan,
#  nan,
#  nan,
#  'nurse',
#  'Not feeling well running a temp',
#  'nurse',
#  'Picked up another shift',
#  nan,
#  nan,
#  nan,
#  'nurse',
#  'Corfirmed for another shift',
#  'admin',
#  'Set nurse status to on hold',
#  nan]

# %%
w_familyemergency = df2[df2['withdrawnInfo_value'].apply(lambda x: x == 'Set "do not return" to the facility')]
sns.countplot(x = 'target', data = w_familyemergency)

# %% [markdown]
# ### <font color = red> can they still apply after with these 3 withdrawn info, what are the cw rate

# %% [markdown]
# ### facilities segmentName: Senior Living = 1, Healthcare = 0

# %%
Senior_Living = df2[df2.apply(lambda x: x['segmentName'] == 'Senior Living', axis = 1)]
Healthcare = df2[df2.apply(lambda x: x['segmentName'] == 'Healthcare', axis = 1)]
Senior_Living['target'].value_counts()
# Out:
# 0    144526
# 1      4110
# Name: target, dtype: int64

# %%
4110/(144526+4110)
# Out:
# 0.02765144379558115

# %%
Healthcare['target'].value_counts()
# Out:
# 0    20758
# 1      260
# Name: target, dtype: int64

# %%
260/(20758+260)
# Out:
# 0.01237034922447426

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(df, col = 'segmentName')
# Notice hwo the arguments come after plt.scatter call
g = g.map(sns.countplot, 'target').add_legend()
# Out:
# /Users/fufufu/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# create type dummy: Senior Living, Healthcare
def create_segmentName_dummy(row):
    if row['segmentName']=='Senior Living':
        return 1
    else:
        return 0
    
df2['segmentName_d'] = df2.apply(lambda row: create_segmentName_dummy(row), axis=1)

# %% [markdown]
# ### <font color = red> dummy

# %% [markdown]
# * Users enableNotifications:
# * Users emailNotifications:
# * Users appNotifications:
# * Users allowedNotifications:

# %% [markdown]
# ### <font color = red> didnt download

# %%
# df2['type_d']
# RN = 1, LVN + LPN = 2, rest = 0
# Senior Living = 1, Healthcare = 0
# df2['segmentName_d']
